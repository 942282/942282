# %% [markdown]
# <a href="https://colab.research.google.com/github/942282/942282/blob/main/Task_2_pencil_sketch___payal_Girhe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("Chameleon.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=427x640 at 0x7F57E2991910>

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=427x640 at 0x7EFC1B5A4450>

# %%
inverted_gray_img=cv2.bitwise_not(gray_img)

# %%
cv2_imshow(inverted_gray_img)
# Out:
# <PIL.Image.Image image mode=L size=427x640 at 0x7EFC19CE6950>

# %%
blurred_img=cv2.GaussianBlur(inverted_gray_img,(21,21),sigmaX=0, sigmaY=0)

# %%
cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=L size=427x640 at 0x7EFC19D00150>

# %%
def dodgev2(x,y):
    return cv2.divide(x, 255-y, scale=256)

# %%
final_img= dodgev2(gray_img, blurred_img)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=427x640 at 0x7EFC19CF0290>
